# %%
import numpy as np
import matplotlib.pyplot as plt 
import math
import time
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#function that will create these 1m samples, n= smaple count 
def sample_generator(n):
    x0 = np.ones(n).reshape(n,1) #intercept value 
    #Sample X1 ~ N(3,4) and sample X2 ~ N(-1, 4)
    x1 = np.random.normal(3,4,n).reshape(n,1) 
    x2 = np.random.normal(-1,4,n).reshape(n,1)
    #theta is fixed with values 3, 1, 2 for generating the data
    theta = np.array([3,1,2]).reshape(3,1)
    #Sample epsilon error in the data from N(0, 2)
    episilon =  np.random.normal(0,math.sqrt(2),n).reshape(n,1) 
    #Make a 1Mx3 matrix
    X = np.hstack((x0, x1, x2)) #feature matrix
    h0 = np.dot(X,theta) #hypotheis function 
    #Generate the value of Y (given X, parameterized by given Theta)
    y = h0 + episilon 
    return X,y

# %%
# the function to calculate the loss 
def l_theta(X, Y, theta):
    m = len(X)
    h0 = np.dot(X, theta)
    loss = h0 - Y
    return loss

# %%
#using direct formula to impute the cost
def j_theta(X, Y,theta):
    m = len(X)
    loss = l_theta(X, Y, theta)
    cost = np.sum(loss **2)
    cost = cost/(2*m)
    return cost

# %%
# r= number of batches 
#b= batch size 
def batch_generator(X,Y,b,r):
    m = len(X)
    left_index = b*r  #is the starting point of the batch 
    right_index = left_index + r #end of the batch 
    if m < right_index:
        new_index = left_index+(right_index - m) #until m will be less than the batch batch end size, then the new index will take the place of left index 
        Xslice = X[left_index:new_index]   
        Yslice = Y[left_index:new_index]
    else:
        Xslice = X[left_index:right_index]  #if the right index> m, then it will keep updating it, the left index will have the value of right index 
        Yslice = Y[left_index:right_index]
    return (Xslice,Yslice)

# %%
def SGD(X,Y,m,r):
    #will initliaze these parameters to zero 
    theta=np.array([0,0,0]).reshape(3,1)
    epoch = 0
    not_converged = True #intially not converged 
    old_cost = 100
    iteration=0
    total_iterations = 0
    #all these parameters will change over each iteration, so I have intialized them as empty arrays that will be updated after evry iteration. 
    cost_arr = []
    theta0 = []
    theta1 = []
    theta2 = []
    episilon = 1e-6 #10^-6
    
    while(not_converged):

        print('epoch :', epoch)
        print('Updated theta:',theta)
        epoch +=1
        #m/r= b gives us the total number of batches 
        # 0.001 = learning rate 
        for b in range(0, math.ceil(m/r)):
            Xslice, Yslice = batch_generator(X,Y,b,r)
            t1 = np.dot(Xslice,theta)
            t2 = t1 - Yslice
            t3 = np.dot(Xslice.T,t2)
            t4 = 0.001*t3
            t5 = t4/r
            theta = theta - t5
            # theta = theta - 0.001*(np.dot(X_Slice.T,loss)/r) direct formula to compute theta 
            #will append all these updated values in these empty arrays 
            theta0.append(theta[0])
            theta1.append(theta[1])
            theta2.append(theta[2])
            
            present_cost = j_theta(Xslice,Yslice,theta)
            cost_arr.append(present_cost)
            iteration +=1
            total_iterations+=1
            #for  batchsize-=1 , when iterations reach 50000, convergence point is found 
            if(r == 1 and total_iterations==50000):
                not_converged = False
                break
            #for  batchesize= 100, when iterations reach 100000, the convergence point is found 
            if(r == 100 and total_iterations==100000):
                not_converged = False
                break
            #at every 1000th iteration the index restarts from zero. at every 1000th iteration the value of theta and cost are updated too 
            if(iteration == 1000):
                
                iteration=0
                list_sum = sum(cost_arr)
                new_cost =list_sum/1000
                cost_arr = []
                print('Previous Cost :',old_cost,'Next Cost :', new_cost,'Difference:', old_cost - new_cost)
                #if the difference between old cost and new cost is less thatn 10^-6 then the convergance point will be found break condition 
                if abs(old_cost - new_cost) < episilon:
                    not_converged = False
                prev_cost = new_cost
                
            
    print('No. of samples :',m,'Batch Size :',r,'Total Iterations:',total_iterations,'No of Epochs :',epoch)
    print('Final Theta :',theta)
    data = np.hstack((theta0, theta1,theta2))
    print(theta.shape)
    return data.T,theta

# %%
#calculate the time taken to reach the convergence point 
#r=1
start_time = time.time()
X1,Y1 = sample_generator(1000000)
data,t2 = SGD(X1,Y1,1000000,1)
end_time = time.time()
print('Execution Time in seconds :',round(end_time - start_time,2) )
# Out:
# epoch : 0
# Updated theta: [[0]
#  [0]
#  [0]]
# Previous Cost : 100 Next Cost : 3.2261728352454977 Difference: 96.77382716475451
# Previous Cost : 100 Next Cost : 1.4281772777080481 Difference: 98.57182272229196
# Previous Cost : 100 Next Cost : 1.3131130356989547 Difference: 98.68688696430104
# Previous Cost : 100 Next Cost : 1.0234159240298746 Difference: 98.97658407597012
# Previous Cost : 100 Next Cost : 0.994183587418566 Difference: 99.00581641258144
# Previous Cost : 100 Next Cost : 1.0290655096883374 Difference: 98.97093449031166
# Previous Cost : 100 Next Cost : 0.9903057577995541 Difference: 99.00969424220044
# Previous Cost : 100 Next Cost : 1.0026626914621213 Difference: 98.99733730853788
# Previous Cost : 100 Next Cost : 1.0388166568183144 Difference: 98.96118334318169
# Previous Cost : 100 Next Cost : 1.014174630758253 Difference: 98.98582536924175
# Previous Cost : 100 Next Cost : 0.9479180696864203 Difference: 99.05208193031358
# Previous Cost : 100 Next Cost : 0.9857502305137764 Difference: 99.01424976948623
# Previous Cost : 100 Next Cost : 0.9697604258040682 Difference: 99.03023957419593
# Previous Cost : 100 Next Cost : 1.0027124265784497 Difference: 98.99728757342154
# Previous Cost : 100 Next Cost : 1.034764221852927 Difference: 98.96523577814708
# Previous Cost : 100 Next Cost : 1.039368225923786 Difference: 98.96063177407622
# Previous Cost : 100 Next Cost : 0.8882614190955663 Difference: 99.11173858090443
# Previous Cost : 100 Next Cost : 0.9507153932583997 Difference: 99.0492846067416
# Previous Cost : 100 Next Cost : 0.9997601373900602 Difference: 99.00023986260994
# Previous Cost : 100 Next Cost : 1.021774473555409 Difference: 98.97822552644459
# Previous Cost : 100 Next Cost : 0.9822088499965052 Difference: 99.01779115000349
# Previous Cost : 100 Next Cost : 1.0136200502959878 Difference: 98.98637994970402
# Previous Cost : 100 Next Cost : 0.9906639311007944 Difference: 99.0093360688992
# Previous Cost : 100 Next Cost : 0.9994732202949397 Difference: 99.00052677970505
# Previous Cost : 100 Next Cost : 0.9492898746914157 Difference: 99.05071012530858
# Previous Cost : 100 Next Cost : 0.9557597037631117 Difference: 99.0442402962369
# Previous Cost : 100 Next Cost : 0.9695887856768352 Difference: 99.03041121432317
# Previous Cost : 100 Next Cost : 0.9214775455836539 Difference: 99.07852245441634
# Previous Cost : 100 Next Cost : 1.0397649478037825 Difference: 98.96023505219621
# Previous Cost : 100 Next Cost : 0.9376569561106938 Difference: 99.0623430438893
# Previous Cost : 100 Next Cost : 0.9768456947498145 Difference: 99.02315430525019
# Previous Cost : 100 Next Cost : 0.9265986657258287 Difference: 99.07340133427417
# Previous Cost : 100 Next Cost : 1.0015858189601738 Difference: 98.99841418103982
# Previous Cost : 100 Next Cost : 1.007410501233124 Difference: 98.99258949876688
# Previous Cost : 100 Next Cost : 0.9648702975535197 Difference: 99.03512970244648
# Previous Cost : 100 Next Cost : 0.880602904151614 Difference: 99.11939709584838
# Previous Cost : 100 Next Cost : 0.9988986976958436 Difference: 99.00110130230415
# Previous Cost : 100 Next Cost : 1.006353868793073 Difference: 98.99364613120693
# Previous Cost : 100 Next Cost : 0.9691318910822758 Difference: 99.03086810891773
# Previous Cost : 100 Next Cost : 0.9870481119703901 Difference: 99.0129518880296
# Previous Cost : 100 Next Cost : 1.050024457757786 Difference: 98.94997554224221
# Previous Cost : 100 Next Cost : 0.9873932801509993 Difference: 99.012606719849
# Previous Cost : 100 Next Cost : 0.9185437276262745 Difference: 99.08145627237373
# Previous Cost : 100 Next Cost : 0.9828497352774472 Difference: 99.01715026472256
# Previous Cost : 100 Next Cost : 0.9477621214339608 Difference: 99.05223787856603
# Previous Cost : 100 Next Cost : 0.9770138379862323 Difference: 99.02298616201377
# Previous Cost : 100 Next Cost : 1.0462760039445334 Difference: 98.95372399605547
# Previous Cost : 100 Next Cost : 0.9448872739061704 Difference: 99.05511272609382
# Previous Cost : 100 Next Cost : 0.8980434507988163 Difference: 99.10195654920119
# No. of samples : 1000000 Batch Size : 1 Total Iterations: 50000 No of Epochs : 1
# Final Theta : [[2.94258289]
#  [1.04495778]
#  [2.00450721]]
# (3, 1)
# Execution Time in seconds : 2.28

# %%
#calculate the time taken to reach the convergence point 
#r= 100
start_time = time.time()
X1,Y1 = sample_generator(1000000)
data,t2 = SGD(X1,Y1,1000000,100)
end_time = time.time()
print('Execution Time in seconds :',round(end_time - start_time,2) )
# Out:
# epoch : 0
# Updated theta: [[0]
#  [0]
#  [0]]
# Previous Cost : 100 Next Cost : 3.3017610258800887 Difference: 96.69823897411992
# Previous Cost : 100 Next Cost : 1.4961483106355917 Difference: 98.50385168936441
# Previous Cost : 100 Next Cost : 1.2875731126348304 Difference: 98.71242688736517
# Previous Cost : 100 Next Cost : 1.168381195890348 Difference: 98.83161880410965
# Previous Cost : 100 Next Cost : 1.0966203499180935 Difference: 98.9033796500819
# Previous Cost : 100 Next Cost : 1.0543279066495843 Difference: 98.94567209335041
# Previous Cost : 100 Next Cost : 1.03129758903517 Difference: 98.96870241096482
# Previous Cost : 100 Next Cost : 1.0140915873887042 Difference: 98.9859084126113
# Previous Cost : 100 Next Cost : 1.020429197818272 Difference: 98.97957080218173
# Previous Cost : 100 Next Cost : 1.0062407889029268 Difference: 98.99375921109707
# epoch : 1
# Updated theta: [[2.81179376]
#  [1.04170895]
#  [1.98749592]]
# Previous Cost : 100 Next Cost : 1.004991409626457 Difference: 98.99500859037354
# Previous Cost : 100 Next Cost : 1.002383388844764 Difference: 98.99761661115524
# Previous Cost : 100 Next Cost : 1.0010863185784127 Difference: 98.99891368142158
# Previous Cost : 100 Next Cost : 1.0025797579275475 Difference: 98.99742024207245
# Previous Cost : 100 Next Cost : 1.0006578035345872 Difference: 98.9993421964654
# Previous Cost : 100 Next Cost : 0.9981370442134422 Difference: 99.00186295578656
# Previous Cost : 100 Next Cost : 0.9990748814252404 Difference: 99.00092511857476
# Previous Cost : 100 Next Cost : 0.9955595703156512 Difference: 99.00444042968435
# Previous Cost : 100 Next Cost : 1.0083617257010198 Difference: 98.99163827429898
# Previous Cost : 100 Next Cost : 1.0003854216501462 Difference: 98.99961457834985
# epoch : 2
# Updated theta: [[2.98450167]
#  [1.00379706]
#  [1.99986298]]
# Previous Cost : 100 Next Cost : 1.001250237884783 Difference: 98.99874976211521
# Previous Cost : 100 Next Cost : 0.9999238994918673 Difference: 99.00007610050814
# Previous Cost : 100 Next Cost : 0.9997993917270462 Difference: 99.00020060827295
# Previous Cost : 100 Next Cost : 1.0018147997029936 Difference: 98.998185200297
# Previous Cost : 100 Next Cost : 1.0002637287719311 Difference: 98.99973627122807
# Previous Cost : 100 Next Cost : 0.997891964668431 Difference: 99.00210803533157
# Previous Cost : 100 Next Cost : 0.9989790745946753 Difference: 99.00102092540533
# Previous Cost : 100 Next Cost : 0.9954992287843758 Difference: 99.00450077121562
# Previous Cost : 100 Next Cost : 1.0082484432031193 Difference: 98.99175155679688
# Previous Cost : 100 Next Cost : 1.0003981840685485 Difference: 98.99960181593146
# epoch : 3
# Updated theta: [[2.99601212]
#  [1.00127035]
#  [2.00068721]]
# Previous Cost : 100 Next Cost : 1.0012352109345326 Difference: 98.99876478906546
# Previous Cost : 100 Next Cost : 0.9998950529262246 Difference: 99.00010494707378
# Previous Cost : 100 Next Cost : 0.9997927153909131 Difference: 99.00020728460909
# Previous Cost : 100 Next Cost : 1.001809502567419 Difference: 98.99819049743257
# Previous Cost : 100 Next Cost : 1.0002641226181022 Difference: 98.9997358773819
# Previous Cost : 100 Next Cost : 0.9978911766471741 Difference: 99.00210882335283
# Previous Cost : 100 Next Cost : 0.998981802808697 Difference: 99.0010181971913
# Previous Cost : 100 Next Cost : 0.9955004252786206 Difference: 99.00449957472138
# Previous Cost : 100 Next Cost : 1.0082439624662665 Difference: 98.99175603753373
# Previous Cost : 100 Next Cost : 1.0004008247187444 Difference: 98.99959917528126
# epoch : 4
# Updated theta: [[2.99677926]
#  [1.00110195]
#  [2.00074214]]
# Previous Cost : 100 Next Cost : 1.0012352501995936 Difference: 98.9987647498004
# Previous Cost : 100 Next Cost : 0.9998937303506763 Difference: 99.00010626964932
# Previous Cost : 100 Next Cost : 0.9997926217519456 Difference: 99.00020737824805
# Previous Cost : 100 Next Cost : 1.0018093524538783 Difference: 98.99819064754612
# Previous Cost : 100 Next Cost : 1.0002642672755175 Difference: 98.99973573272449
# Previous Cost : 100 Next Cost : 0.997891193179493 Difference: 99.0021088068205
# Previous Cost : 100 Next Cost : 0.9989820251161339 Difference: 99.00101797488387
# Previous Cost : 100 Next Cost : 0.9955005281990538 Difference: 99.00449947180094
# Previous Cost : 100 Next Cost : 1.0082436774715928 Difference: 98.9917563225284
# Previous Cost : 100 Next Cost : 1.0004010086612325 Difference: 98.99959899133877
# epoch : 5
# Updated theta: [[2.99683039]
#  [1.00109073]
#  [2.0007458 ]]
# Previous Cost : 100 Next Cost : 1.0012352574393812 Difference: 98.99876474256062
# Previous Cost : 100 Next Cost : 0.9998936448699521 Difference: 99.00010635513004
# Previous Cost : 100 Next Cost : 0.9997926170716849 Difference: 99.00020738292831
# Previous Cost : 100 Next Cost : 1.0018093433506194 Difference: 98.99819065664938
# Previous Cost : 100 Next Cost : 1.0002642774424457 Difference: 98.99973572255756
# Previous Cost : 100 Next Cost : 0.997891194588034 Difference: 99.00210880541196
# Previous Cost : 100 Next Cost : 0.9989820401120558 Difference: 99.00101795988795
# Previous Cost : 100 Next Cost : 0.9955005351613364 Difference: 99.00449946483866
# Previous Cost : 100 Next Cost : 1.0082436585381183 Difference: 98.99175634146188
# Previous Cost : 100 Next Cost : 1.0004010209557572 Difference: 98.99959897904424
# epoch : 6
# Updated theta: [[2.9968338 ]
#  [1.00108998]
#  [2.00074605]]
# Previous Cost : 100 Next Cost : 1.0012352579424253 Difference: 98.99876474205757
# Previous Cost : 100 Next Cost : 0.9998936391847593 Difference: 99.00010636081524
# Previous Cost : 100 Next Cost : 0.9997926167666921 Difference: 99.0002073832333
# Previous Cost : 100 Next Cost : 1.001809342747919 Difference: 98.99819065725208
# Previous Cost : 100 Next Cost : 1.0002642781223756 Difference: 98.99973572187763
# Previous Cost : 100 Next Cost : 0.9978911946832717 Difference: 99.00210880531672
# Previous Cost : 100 Next Cost : 0.9989820411122844 Difference: 99.00101795888772
# Previous Cost : 100 Next Cost : 0.9955005356258109 Difference: 99.00449946437419
# Previous Cost : 100 Next Cost : 1.0082436572765272 Difference: 98.99175634272348
# Previous Cost : 100 Next Cost : 1.000401021775306 Difference: 98.9995989782247
# epoch : 7
# Updated theta: [[2.99683402]
#  [1.00108993]
#  [2.00074606]]
# Previous Cost : 100 Next Cost : 1.0012352579760428 Difference: 98.99876474202395
# Previous Cost : 100 Next Cost : 0.99989363880591 Difference: 99.00010636119409
# Previous Cost : 100 Next Cost : 0.9997926167463959 Difference: 99.00020738325361
# Previous Cost : 100 Next Cost : 1.0018093427077688 Difference: 98.99819065729223
# Previous Cost : 100 Next Cost : 1.0002642781677014 Difference: 98.9997357218323
# Previous Cost : 100 Next Cost : 0.9978911946896245 Difference: 99.00210880531037
# Previous Cost : 100 Next Cost : 0.9989820411789528 Difference: 99.00101795882105
# Previous Cost : 100 Next Cost : 0.9955005356567687 Difference: 99.00449946434323
# Previous Cost : 100 Next Cost : 1.008243657192448 Difference: 98.99175634280755
# Previous Cost : 100 Next Cost : 1.000401021829927 Difference: 98.99959897817007
# epoch : 8
# Updated theta: [[2.99683404]
#  [1.00108993]
#  [2.00074606]]
# Previous Cost : 100 Next Cost : 1.0012352579782837 Difference: 98.99876474202172
# Previous Cost : 100 Next Cost : 0.9998936387806612 Difference: 99.00010636121934
# Previous Cost : 100 Next Cost : 0.9997926167450434 Difference: 99.00020738325496
# Previous Cost : 100 Next Cost : 1.0018093427050914 Difference: 98.99819065729491
# Previous Cost : 100 Next Cost : 1.000264278170722 Difference: 98.99973572182928
# Previous Cost : 100 Next Cost : 0.9978911946900486 Difference: 99.00210880530994
# Previous Cost : 100 Next Cost : 0.9989820411833947 Difference: 99.0010179588166
# Previous Cost : 100 Next Cost : 0.9955005356588326 Difference: 99.00449946434117
# Previous Cost : 100 Next Cost : 1.0082436571868447 Difference: 98.99175634281316
# Previous Cost : 100 Next Cost : 1.0004010218335682 Difference: 98.99959897816643
# epoch : 9
# Updated theta: [[2.99683404]
#  [1.00108993]
#  [2.00074606]]
# Previous Cost : 100 Next Cost : 1.001235257978433 Difference: 98.99876474202156
# Previous Cost : 100 Next Cost : 0.9998936387789771 Difference: 99.00010636122103
# Previous Cost : 100 Next Cost : 0.9997926167449527 Difference: 99.00020738325505
# Previous Cost : 100 Next Cost : 1.001809342704913 Difference: 98.99819065729508
# Previous Cost : 100 Next Cost : 1.0002642781709232 Difference: 98.99973572182908
# Previous Cost : 100 Next Cost : 0.9978911946900757 Difference: 99.00210880530993
# Previous Cost : 100 Next Cost : 0.9989820411836907 Difference: 99.0010179588163
# Previous Cost : 100 Next Cost : 0.9955005356589685 Difference: 99.00449946434104
# Previous Cost : 100 Next Cost : 1.008243657186471 Difference: 98.99175634281353
# No. of samples : 1000000 Batch Size : 100 Total Iterations: 100000 No of Epochs : 10
# Final Theta : [[2.99683404]
#  [1.00108993]
#  [2.00074606]]
# (3, 1)
# Execution Time in seconds : 5.26

# %%
#calculate the time taken to reach the convergence point 
#r=10000
start_time = time.time()
X1,Y1 = sample_generator(1000000)
data,t2 = SGD(X1,Y1,1000000,10000)
end_time = time.time()
print('Execution Time in seconds :',round(end_time - start_time,2) )
# Out:
# Streaming output truncated to the last 5000 lines.
#  [1.00014794]
#  [2.0005233 ]]
# Previous Cost : 100 Next Cost : 0.998636740520577 Difference: 99.00136325947942
# epoch : 167170
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167171
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167172
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167173
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167174
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167175
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167176
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167177
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167178
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167179
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# Previous Cost : 100 Next Cost : 0.998636740520577 Difference: 99.00136325947942
# epoch : 167180
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167181
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167182
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167183
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167184
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167185
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167186
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167187
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167188
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167189
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# Previous Cost : 100 Next Cost : 0.998636740520577 Difference: 99.00136325947942
# epoch : 167190
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167191
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167192
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167193
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167194
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167195
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167196
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167197
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167198
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167199
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# Previous Cost : 100 Next Cost : 0.998636740520577 Difference: 99.00136325947942
# epoch : 167200
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167201
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167202
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167203
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167204
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167205
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167206
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167207
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167208
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167209
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# Previous Cost : 100 Next Cost : 0.998636740520577 Difference: 99.00136325947942
# epoch : 167210
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167211
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167212
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167213
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167214
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167215
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167216
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167217
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167218
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167219
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# Previous Cost : 100 Next Cost : 0.998636740520577 Difference: 99.00136325947942
# epoch : 167220
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167221
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167222
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167223
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167224
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167225
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167226
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167227
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167228
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167229
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# Previous Cost : 100 Next Cost : 0.998636740520577 Difference: 99.00136325947942
# epoch : 167230
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167231
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167232
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167233
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167234
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167235
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167236
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167237
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167238
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167239
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# Previous Cost : 100 Next Cost : 0.998636740520577 Difference: 99.00136325947942
# epoch : 167240
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167241
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167242
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167243
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167244
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167245
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167246
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167247
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167248
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167249
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# Previous Cost : 100 Next Cost : 0.998636740520577 Difference: 99.00136325947942
# epoch : 167250
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167251
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167252
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167253
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167254
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167255
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167256
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167257
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167258
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167259
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# Previous Cost : 100 Next Cost : 0.998636740520577 Difference: 99.00136325947942
# epoch : 167260
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167261
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167262
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167263
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167264
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167265
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167266
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167267
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167268
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167269
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# Previous Cost : 100 Next Cost : 0.998636740520577 Difference: 99.00136325947942
# epoch : 167270
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167271
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167272
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167273
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167274
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167275
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167276
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167277
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167278
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167279
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# Previous Cost : 100 Next Cost : 0.998636740520577 Difference: 99.00136325947942
# epoch : 167280
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167281
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167282
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167283
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167284
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167285
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167286
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167287
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167288
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167289
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# Previous Cost : 100 Next Cost : 0.998636740520577 Difference: 99.00136325947942
# epoch : 167290
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167291
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167292
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167293
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167294
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167295
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167296
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167297
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167298
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167299
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# Previous Cost : 100 Next Cost : 0.998636740520577 Difference: 99.00136325947942
# epoch : 167300
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167301
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167302
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167303
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167304
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167305
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167306
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167307
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167308
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167309
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# Previous Cost : 100 Next Cost : 0.998636740520577 Difference: 99.00136325947942
# epoch : 167310
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167311
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167312
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167313
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167314
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167315
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167316
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167317
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167318
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167319
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# Previous Cost : 100 Next Cost : 0.998636740520577 Difference: 99.00136325947942
# epoch : 167320
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167321
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167322
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167323
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167324
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167325
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167326
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167327
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167328
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167329
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# Previous Cost : 100 Next Cost : 0.998636740520577 Difference: 99.00136325947942
# epoch : 167330
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167331
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167332
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167333
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167334
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167335
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167336
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167337
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167338
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167339
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# Previous Cost : 100 Next Cost : 0.998636740520577 Difference: 99.00136325947942
# epoch : 167340
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167341
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167342
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167343
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167344
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167345
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167346
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167347
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167348
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167349
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# Previous Cost : 100 Next Cost : 0.998636740520577 Difference: 99.00136325947942
# epoch : 167350
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167351
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167352
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167353
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167354
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167355
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167356
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167357
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167358
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167359
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# Previous Cost : 100 Next Cost : 0.998636740520577 Difference: 99.00136325947942
# epoch : 167360
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167361
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167362
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167363
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167364
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167365
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167366
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167367
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167368
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167369
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# Previous Cost : 100 Next Cost : 0.998636740520577 Difference: 99.00136325947942
# epoch : 167370
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167371
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167372
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167373
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167374
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167375
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167376
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167377
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167378
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167379
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# Previous Cost : 100 Next Cost : 0.998636740520577 Difference: 99.00136325947942
# epoch : 167380
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167381
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167382
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167383
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167384
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167385
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167386
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167387
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167388
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167389
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# Previous Cost : 100 Next Cost : 0.998636740520577 Difference: 99.00136325947942
# epoch : 167390
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167391
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167392
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167393
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167394
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167395
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167396
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167397
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167398
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167399
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# Previous Cost : 100 Next Cost : 0.998636740520577 Difference: 99.00136325947942
# epoch : 167400
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167401
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167402
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167403
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167404
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167405
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167406
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167407
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167408
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167409
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# Previous Cost : 100 Next Cost : 0.998636740520577 Difference: 99.00136325947942
# epoch : 167410
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167411
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167412
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167413
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167414
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167415
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167416
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167417
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167418
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167419
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# Previous Cost : 100 Next Cost : 0.998636740520577 Difference: 99.00136325947942
# epoch : 167420
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167421
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167422
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167423
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167424
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167425
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167426
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167427
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167428
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167429
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# Previous Cost : 100 Next Cost : 0.998636740520577 Difference: 99.00136325947942
# epoch : 167430
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167431
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167432
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167433
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167434
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167435
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167436
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167437
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167438
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167439
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# Previous Cost : 100 Next Cost : 0.998636740520577 Difference: 99.00136325947942
# epoch : 167440
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167441
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167442
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167443
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167444
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167445
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167446
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167447
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167448
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167449
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# Previous Cost : 100 Next Cost : 0.998636740520577 Difference: 99.00136325947942
# epoch : 167450
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167451
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167452
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167453
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167454
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167455
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167456
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167457
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167458
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167459
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# Previous Cost : 100 Next Cost : 0.998636740520577 Difference: 99.00136325947942
# epoch : 167460
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167461
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167462
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167463
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167464
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167465
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167466
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167467
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167468
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167469
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# Previous Cost : 100 Next Cost : 0.998636740520577 Difference: 99.00136325947942
# epoch : 167470
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167471
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167472
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167473
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167474
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167475
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167476
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167477
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167478
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167479
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# Previous Cost : 100 Next Cost : 0.998636740520577 Difference: 99.00136325947942
# epoch : 167480
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167481
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167482
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167483
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167484
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167485
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167486
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167487
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167488
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167489
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# Previous Cost : 100 Next Cost : 0.998636740520577 Difference: 99.00136325947942
# epoch : 167490
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167491
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167492
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167493
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167494
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167495
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167496
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167497
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167498
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167499
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# Previous Cost : 100 Next Cost : 0.998636740520577 Difference: 99.00136325947942
# epoch : 167500
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167501
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167502
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167503
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167504
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167505
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167506
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167507
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167508
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167509
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# Previous Cost : 100 Next Cost : 0.998636740520577 Difference: 99.00136325947942
# epoch : 167510
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167511
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167512
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167513
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167514
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167515
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167516
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167517
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167518
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167519
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# Previous Cost : 100 Next Cost : 0.998636740520577 Difference: 99.00136325947942
# epoch : 167520
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167521
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167522
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167523
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167524
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167525
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167526
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167527
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167528
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167529
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# Previous Cost : 100 Next Cost : 0.998636740520577 Difference: 99.00136325947942
# epoch : 167530
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167531
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167532
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167533
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167534
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167535
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167536
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167537
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167538
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167539
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# Previous Cost : 100 Next Cost : 0.998636740520577 Difference: 99.00136325947942
# epoch : 167540
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167541
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167542
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167543
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167544
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167545
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167546
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167547
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167548
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167549
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# Previous Cost : 100 Next Cost : 0.998636740520577 Difference: 99.00136325947942
# epoch : 167550
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167551
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167552
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167553
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167554
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167555
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167556
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167557
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167558
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167559
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# Previous Cost : 100 Next Cost : 0.998636740520577 Difference: 99.00136325947942
# epoch : 167560
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167561
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167562
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167563
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167564
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167565
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167566
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167567
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167568
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167569
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# Previous Cost : 100 Next Cost : 0.998636740520577 Difference: 99.00136325947942
# epoch : 167570
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167571
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167572
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167573
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167574
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167575
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167576
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167577
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167578
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167579
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# Previous Cost : 100 Next Cost : 0.998636740520577 Difference: 99.00136325947942
# epoch : 167580
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167581
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167582
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167583
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167584
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167585
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167586
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167587
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167588
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167589
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# Previous Cost : 100 Next Cost : 0.998636740520577 Difference: 99.00136325947942
# epoch : 167590
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167591
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167592
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167593
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167594
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167595
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167596
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167597
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167598
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167599
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# Previous Cost : 100 Next Cost : 0.998636740520577 Difference: 99.00136325947942
# epoch : 167600
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167601
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167602
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167603
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167604
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167605
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167606
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167607
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167608
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167609
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# Previous Cost : 100 Next Cost : 0.998636740520577 Difference: 99.00136325947942
# epoch : 167610
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167611
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167612
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167613
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167614
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167615
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167616
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167617
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167618
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167619
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# Previous Cost : 100 Next Cost : 0.998636740520577 Difference: 99.00136325947942
# epoch : 167620
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167621
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167622
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167623
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167624
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167625
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167626
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167627
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167628
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167629
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# Previous Cost : 100 Next Cost : 0.998636740520577 Difference: 99.00136325947942
# epoch : 167630
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167631
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167632
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167633
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167634
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167635
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167636
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167637
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167638
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167639
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# Previous Cost : 100 Next Cost : 0.998636740520577 Difference: 99.00136325947942
# epoch : 167640
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167641
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167642
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167643
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167644
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167645
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167646
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167647
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167648
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167649
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# Previous Cost : 100 Next Cost : 0.998636740520577 Difference: 99.00136325947942
# epoch : 167650
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167651
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167652
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167653
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167654
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167655
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167656
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167657
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167658
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167659
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# Previous Cost : 100 Next Cost : 0.998636740520577 Difference: 99.00136325947942
# epoch : 167660
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167661
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167662
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167663
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167664
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167665
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167666
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167667
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167668
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167669
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# Previous Cost : 100 Next Cost : 0.998636740520577 Difference: 99.00136325947942
# epoch : 167670
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167671
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167672
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167673
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167674
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167675
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167676
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167677
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167678
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167679
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# Previous Cost : 100 Next Cost : 0.998636740520577 Difference: 99.00136325947942
# epoch : 167680
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167681
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167682
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167683
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167684
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167685
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167686
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167687
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167688
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167689
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# Previous Cost : 100 Next Cost : 0.998636740520577 Difference: 99.00136325947942
# epoch : 167690
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167691
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167692
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167693
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167694
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167695
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167696
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167697
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167698
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167699
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# Previous Cost : 100 Next Cost : 0.998636740520577 Difference: 99.00136325947942
# epoch : 167700
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167701
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167702
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167703
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167704
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167705
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167706
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167707
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167708
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167709
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# Previous Cost : 100 Next Cost : 0.998636740520577 Difference: 99.00136325947942
# epoch : 167710
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167711
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167712
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167713
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167714
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167715
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167716
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167717
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167718
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167719
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# Previous Cost : 100 Next Cost : 0.998636740520577 Difference: 99.00136325947942
# epoch : 167720
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167721
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167722
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167723
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167724
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167725
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167726
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167727
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167728
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167729
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# Previous Cost : 100 Next Cost : 0.998636740520577 Difference: 99.00136325947942
# epoch : 167730
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167731
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167732
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167733
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167734
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167735
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167736
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167737
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167738
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167739
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# Previous Cost : 100 Next Cost : 0.998636740520577 Difference: 99.00136325947942
# epoch : 167740
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167741
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167742
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167743
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167744
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167745
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167746
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167747
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167748
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167749
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# Previous Cost : 100 Next Cost : 0.998636740520577 Difference: 99.00136325947942
# epoch : 167750
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167751
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167752
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167753
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167754
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167755
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167756
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167757
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167758
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 167759
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# Previous Cost : 100 Next Cost : 0.998636740520577 Difference: 99.00136325947942
# epoch : 167760
# Updated theta: [[3.00004329]
# ...
#  [2.0005233 ]]
# epoch : 168191
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 168192
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 168193
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 168194
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 168195
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 168196
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 168197
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 168198
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 168199
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# Previous Cost : 100 Next Cost : 0.998636740520577 Difference: 99.00136325947942
# epoch : 168200
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 168201
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 168202
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 168203
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 168204
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 168205
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 168206
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 168207
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 168208
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 168209
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# Previous Cost : 100 Next Cost : 0.998636740520577 Difference: 99.00136325947942
# epoch : 168210
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 168211
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 168212
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 168213
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 168214
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 168215
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 168216
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 168217
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 168218
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 168219
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# Previous Cost : 100 Next Cost : 0.998636740520577 Difference: 99.00136325947942
# epoch : 168220
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 168221
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 168222
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 168223
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 168224
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 168225
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 168226
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 168227
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 168228
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 168229
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# Previous Cost : 100 Next Cost : 0.998636740520577 Difference: 99.00136325947942
# epoch : 168230
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 168231
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 168232
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 168233
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 168234
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 168235
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 168236
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 168237
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 168238
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 168239
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# Previous Cost : 100 Next Cost : 0.998636740520577 Difference: 99.00136325947942
# epoch : 168240
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 168241
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 168242
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 168243
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 168244
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 168245
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 168246
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 168247
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 168248
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 168249
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# Previous Cost : 100 Next Cost : 0.998636740520577 Difference: 99.00136325947942
# epoch : 168250
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 168251
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 168252
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 168253
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 168254
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 168255
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 168256
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 168257
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 168258
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 168259
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# Previous Cost : 100 Next Cost : 0.998636740520577 Difference: 99.00136325947942
# epoch : 168260
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 168261
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 168262
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 168263
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 168264
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 168265
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 168266
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 168267
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 168268
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 168269
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# Previous Cost : 100 Next Cost : 0.998636740520577 Difference: 99.00136325947942
# epoch : 168270
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 168271
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 168272
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 168273
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 168274
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 168275
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 168276
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 168277
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 168278
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 168279
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# Previous Cost : 100 Next Cost : 0.998636740520577 Difference: 99.00136325947942
# epoch : 168280
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 168281
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 168282
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 168283
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 168284
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 168285
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 168286
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 168287
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 168288
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 168289
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# Previous Cost : 100 Next Cost : 0.998636740520577 Difference: 99.00136325947942
# epoch : 168290
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 168291
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 168292
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 168293
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 168294
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 168295
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 168296
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 168297
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 168298
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 168299
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# Previous Cost : 100 Next Cost : 0.998636740520577 Difference: 99.00136325947942
# epoch : 168300
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 168301
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 168302
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 168303
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 168304
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 168305
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 168306
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 168307
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 168308
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 168309
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# Previous Cost : 100 Next Cost : 0.998636740520577 Difference: 99.00136325947942
# epoch : 168310
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 168311
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 168312
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 168313
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 168314
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 168315
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 168316
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 168317
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 168318
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 168319
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# Previous Cost : 100 Next Cost : 0.998636740520577 Difference: 99.00136325947942
# epoch : 168320
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 168321
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 168322
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 168323
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 168324
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 168325
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 168326
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 168327
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 168328
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 168329
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# Previous Cost : 100 Next Cost : 0.998636740520577 Difference: 99.00136325947942
# epoch : 168330
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 168331
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 168332
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 168333
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 168334
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 168335
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 168336
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 168337
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 168338
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 168339
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# Previous Cost : 100 Next Cost : 0.998636740520577 Difference: 99.00136325947942
# epoch : 168340
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 168341
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 168342
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 168343
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 168344
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 168345
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 168346
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 168347
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 168348
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 168349
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# Previous Cost : 100 Next Cost : 0.998636740520577 Difference: 99.00136325947942
# epoch : 168350
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 168351
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 168352
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 168353
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 168354
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 168355
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 168356
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 168357
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 168358
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 168359
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# Previous Cost : 100 Next Cost : 0.998636740520577 Difference: 99.00136325947942
# epoch : 168360
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 168361
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 168362
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 168363
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 168364
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 168365
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 168366
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 168367
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 168368
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 168369
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# Previous Cost : 100 Next Cost : 0.998636740520577 Difference: 99.00136325947942
# epoch : 168370
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 168371
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 168372
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 168373
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 168374
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 168375
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 168376
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 168377
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 168378
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 168379
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# Previous Cost : 100 Next Cost : 0.998636740520577 Difference: 99.00136325947942
# epoch : 168380
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 168381
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 168382
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 168383
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 168384
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 168385
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 168386
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 168387
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]
# epoch : 168388
# Updated theta: [[3.00004329]
#  [1.00014794]
#  [2.0005233 ]]

# %%
#calculate the time taken to reach the convergence point 
#r=1000000
start_time = time.time()
X1,Y1 = sample_generator(1000000)
data,t2 = SGD(X1,Y1,1000000,1000000)
end_time = time.time()
print('Execution Time in seconds :',round(end_time - start_time,2) )
# Out:
# epoch : 0
# Updated theta: [[0]
#  [0]
#  [0]]
# Previous Cost : 100 Next Cost : 3.2455712315774505 Difference: 96.75442876842254
# Previous Cost : 100 Next Cost : 1.480909130585813 Difference: 98.51909086941419
# Previous Cost : 100 Next Cost : 1.2542441944469003 Difference: 98.7457558055531
# Previous Cost : 100 Next Cost : 1.128869931805428 Difference: 98.87113006819457
# Previous Cost : 100 Next Cost : 1.037856992309763 Difference: 98.96214300769023
# Previous Cost : 100 Next Cost : 1.0077733106780267 Difference: 98.99222668932197
# Previous Cost : 100 Next Cost : 0.9978860752257902 Difference: 99.0021139247742
# Previous Cost : 100 Next Cost : 1.0173746454623742 Difference: 98.98262535453763
# Previous Cost : 100 Next Cost : 1.0117136393807729 Difference: 98.98828636061923
# Previous Cost : 100 Next Cost : 0.9989075346816153 Difference: 99.00109246531838
# Previous Cost : 100 Next Cost : 0.9307218390378439 Difference: 99.06927816096216
# Previous Cost : 100 Next Cost : 0.904005331319307 Difference: 99.09599466868069
# Previous Cost : 100 Next Cost : 1.1021090412468963 Difference: 98.89789095875311
# Previous Cost : 100 Next Cost : 0.9396931833821717 Difference: 99.06030681661782
# Previous Cost : 100 Next Cost : 1.006574754615965 Difference: 98.99342524538403
# Previous Cost : 100 Next Cost : 0.9218485631527362 Difference: 99.07815143684726
# Previous Cost : 100 Next Cost : 0.9649918727004204 Difference: 99.03500812729958
# Previous Cost : 100 Next Cost : 0.9910569877853008 Difference: 99.0089430122147
# Previous Cost : 100 Next Cost : 1.0188502338606937 Difference: 98.98114976613931
# Previous Cost : 100 Next Cost : 0.9222229508593319 Difference: 99.07777704914066
# Previous Cost : 100 Next Cost : 0.9909681850006314 Difference: 99.00903181499937
# Previous Cost : 100 Next Cost : 0.9838186099871763 Difference: 99.01618139001282
# Previous Cost : 100 Next Cost : 1.0074862173162509 Difference: 98.99251378268374
# Previous Cost : 100 Next Cost : 0.9698783808616348 Difference: 99.03012161913837
# Previous Cost : 100 Next Cost : 0.9662471500071379 Difference: 99.03375284999287
# Previous Cost : 100 Next Cost : 0.9570389925559811 Difference: 99.04296100744402
# Previous Cost : 100 Next Cost : 0.9601861196910668 Difference: 99.03981388030893
# Previous Cost : 100 Next Cost : 0.9876274004966888 Difference: 99.01237259950331
# Previous Cost : 100 Next Cost : 0.9630808451675319 Difference: 99.03691915483247
# Previous Cost : 100 Next Cost : 0.9512399978484262 Difference: 99.04876000215157
# Previous Cost : 100 Next Cost : 0.946963856923351 Difference: 99.05303614307665
# Previous Cost : 100 Next Cost : 0.944538909072064 Difference: 99.05546109092793
# Previous Cost : 100 Next Cost : 0.9738975546808669 Difference: 99.02610244531914
# Previous Cost : 100 Next Cost : 0.9804023752552871 Difference: 99.01959762474472
# Previous Cost : 100 Next Cost : 0.9913541961140663 Difference: 99.00864580388594
# Previous Cost : 100 Next Cost : 0.9386049514171794 Difference: 99.06139504858282
# Previous Cost : 100 Next Cost : 1.0046461436867897 Difference: 98.99535385631322
# Previous Cost : 100 Next Cost : 0.885939911929993 Difference: 99.11406008807
# Previous Cost : 100 Next Cost : 0.9708695422541257 Difference: 99.02913045774588
# Previous Cost : 100 Next Cost : 0.9623431687044666 Difference: 99.03765683129554
# Previous Cost : 100 Next Cost : 1.0178611890850935 Difference: 98.9821388109149
# Previous Cost : 100 Next Cost : 1.0005486253672662 Difference: 98.99945137463273
# Previous Cost : 100 Next Cost : 1.0127744221620663 Difference: 98.98722557783793
# Previous Cost : 100 Next Cost : 0.9462886607944692 Difference: 99.05371133920553
# Previous Cost : 100 Next Cost : 0.937493444333637 Difference: 99.06250655566636
# Previous Cost : 100 Next Cost : 1.0368882238487496 Difference: 98.96311177615125
# Previous Cost : 100 Next Cost : 0.9103831736140163 Difference: 99.08961682638598
# Previous Cost : 100 Next Cost : 0.9762938522003604 Difference: 99.02370614779964
# Previous Cost : 100 Next Cost : 0.9417143399814116 Difference: 99.05828566001858
# No. of samples : 1000000 Batch Size : 1 Total Iterations: 50000 No of Epochs : 1
# Final Theta : [[2.96354437]
#  [0.95692492]
#  [1.98497986]]
# (3, 1)
# Execution Time in seconds : 2.21

# %%
#checking out the dataset 
check= pd.read_csv("/content/drive/MyDrive/ML IITD/ass1/Q2/q2test.csv", header=None, skiprows=1)
check.head()
# Out:
#         0       1       2
# 0  16.678  13.018  45.537
# 1   6.583  -5.539  -1.170
# 2 -19.837   6.089  -3.646
# 3  -8.412   6.110   8.137
# 4   1.052  11.595  25.781

# %%
# now I will compute the test error with respect to the prediction of the original hypothesis, and compare with the error obtained using the learned
## hypothesis in each case. 
# I will generate a function that will read the data from the dataset 
#I will split and initilise the Ytest and Xtest vectors 
def read_test():
    dataset= pd.read_csv("/content/drive/MyDrive/ML IITD/ass1/Q2/q2test.csv", header=None, skiprows=1)
    Ytest = dataset[2].values
    m = len(Ytest)
    Xtest = dataset[[0,1]]
    Xtest = np.array(Xtest)
    identity_arr = np.ones(m)
    identity_arr = identity_arr.reshape(m,1) #have to reshape into (m,1) vector form 
    Xtest= np.hstack((identity_arr,Xtest))
    return Xtest,Ytest

# %%
# I will define a test function that will compute the test error 
def test_error():
    X,Y = read_test()
    original_theta = np.array([3,1,2])
    theta0t = np.array([2.94258289,1.04495778, 2.00450721])
    theta1t = np.array([2.99683404 , 1.00108993, 2.00074606])
    theta3t = np.array([2.96354437, 0.95692492, 1.98497986])
    theta_arr2=np.vstack((theta0t,theta1t,theta3t))  #will stack these values into a single 
    for i in range(0,3):
        original_cost = j_theta(X, Y, original_theta) #the cost computed from this dataset
        print('original cost :',original_cost) 
        my_cost = j_theta(X, Y, theta_arr2[i])  #the cost computed earleir, using the ttetas in the matrix 
        print('My Theta :',theta_arr2[i])  #the first value of array of thetas computed 
        print('My Cost :',my_cost) #the cost I calculated earlier 
        print('Error difference :',my_cost - original_cost) #the error difference

# %%
test_error()
# Out:
# original cost : 0.9829469215
# My Theta : [2.94258289 1.04495778 2.00450721]
# My Cost : 1.0819801635100443
# Error difference : 0.09903324201004438
# original cost : 0.9829469215
# My Theta : [2.99683404 1.00108993 2.00074606]
# My Cost : 0.9828868121965965
# Error difference : -6.01093034034994e-05
# original cost : 0.9829469215
# My Theta : [2.96354437 0.95692492 1.98497986]
# My Cost : 1.0943214807879795
# Error difference : 0.11137455928797957
